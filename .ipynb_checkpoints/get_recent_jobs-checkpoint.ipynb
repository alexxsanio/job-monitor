# %%
import csv
from jobspy import scrape_jobs

jobs = scrape_jobs(
    site_name=["linkedin"], # "glassdoor", "bayt", "naukri", "bdjobs"
    search_term="backend software engineer",
    google_search_term="backend software engineer jobs near San Francisco, CA posted in the past week",
    location="San Francisco, CA",
    results_wanted=4000,
    hours_old=24*7,
    country_indeed='USA',
    
    linkedin_fetch_description=True # gets more info such as description, direct job url (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
)
print(f"Found {len(jobs)} jobs")
print(jobs.head())
jobs.to_csv("jobs.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel
# Out:
# 2025-11-17 02:00:31,006 - INFO - JobSpy:Linkedin - finished scraping
# Found 20 jobs
#               id      site                                        job_url  \
# 0  li-4164164423  linkedin  https://www.linkedin.com/jobs/view/4164164423
# 1  li-4336235736  linkedin  https://www.linkedin.com/jobs/view/4336235736
# 2  li-4318372027  linkedin  https://www.linkedin.com/jobs/view/4318372027
# 3  li-4315426715  linkedin  https://www.linkedin.com/jobs/view/4315426715
# 4  li-4310488505  linkedin  https://www.linkedin.com/jobs/view/4310488505
#
#   job_url_direct                                              title  \
# 0           None  Backend Software Engineer, CloudKitchens - New...
# 1           None                                Software Engineer 1
# 2           None                        Associate Software Engineer
# 3           None                         Software Engineer, Backend
# 4           None                         Software Engineer, Backend
#
#           company           location date_posted job_type salary_source  ...  \
# 0   CloudKitchens       New York, NY  2025-11-15     None          None  ...
# 1          Intuit      San Diego, CA  2025-11-15     None          None  ...
# 2  Morgan Stanley       New York, NY  2025-11-15     None          None  ...
# 3       Robinhood       New York, NY  2025-11-15     None          None  ...
# 4            Calm  San Francisco, CA  2025-11-15     None          None  ...
#
#   company_addresses company_num_employees company_revenue company_description  \
# 0              None                  None            None                None
# 1              None                  None            None                None
# 2              None                  None            None                None
# 3              None                  None            None                None
# 4              None                  None            None                None
#
#    skills experience_range company_rating company_reviews_count vacancy_count  \
# 0    None             None           None                  None          None
# 1    None             None           None                  None          None
# 2    None             None           None                  None          None
# 3    None             None           None                  None          None
# 4    None             None           None                  None          None
#
#   work_from_home_type
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
#
# [5 rows x 34 columns]
