# %%
import csv
from jobspy import scrape_jobs

jobs = scrape_jobs(
    site_name=["linkedin"], # "glassdoor", "bayt", "naukri", "bdjobs"
    search_term="backend software engineer",
    google_search_term="backend software engineer jobs near Tucson, AL posted in the past week",
    location="Tucson, AL",
    results_wanted=200,
    hours_old=24*7,
    country_indeed='USA',
    distance=50,
    
    linkedin_fetch_description=True # gets more info such as description, direct job url (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
)
print(f"Found {len(jobs)} jobs")
print(jobs.head())
jobs.to_csv("data/backend_engineer/jobs_ALTucson.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel
# Out:
# Found 30 jobs
#               id      site                                        job_url  \
# 0  li-4320006275  linkedin  https://www.linkedin.com/jobs/view/4320006275
# 1  li-4340653568  linkedin  https://www.linkedin.com/jobs/view/4340653568
# 2  li-4338362889  linkedin  https://www.linkedin.com/jobs/view/4338362889
# 3  li-3908046162  linkedin  https://www.linkedin.com/jobs/view/3908046162
# 4  li-4338222568  linkedin  https://www.linkedin.com/jobs/view/4338222568
#
#   job_url_direct                                      title  \
# 0            NaN                Software Developer - GOLANG
# 1            NaN                           Systems Engineer
# 2            NaN  Data Engineer II - Information Technology
# 3            NaN                  Computer Systems Engineer
# 4            NaN                          Software Engineer
#
#                             company    location date_posted  job_type  \
# ...
